# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

df_test = pd.read_csv("https://raw.githubusercontent.com/kup-kup/telemarketing-prediction/refs/heads/main/processed-data/test.csv")
df_train = pd.read_csv("https://raw.githubusercontent.com/kup-kup/telemarketing-prediction/refs/heads/main/processed-data/train.csv")

# %%
df_train.head()
# Out:
#         age  education  campaign  previous  cons.conf.idx      y  \
# 0  0.863739  -0.714094  0.522981 -0.350127      -0.322269  False
# 1 -0.289722   1.142561 -0.203688  1.653813      -0.322269  False
# 2  3.651268  -1.951863 -0.567023 -0.350127       0.045048   True
# 3 -0.385843   1.142561 -0.203688 -0.350127       0.887717  False
# 4  1.824956   1.142561 -0.203688 -0.350127      -0.062987  False
#
#    marital_married  marital_single  job_blue-collar  job_entrepreneur  ...  \
# 0             True           False             True             False  ...
# 1             True           False            False              True  ...
# 2             True           False            False             False  ...
# 3             True           False            False             False  ...
# 4            False           False            False             False  ...
#
#    month_mar  month_may  month_nov  month_oct  month_sep  day_of_week_mon  \
# 0      False      False       True      False      False            False
# 1      False      False       True      False      False            False
# 2      False      False      False      False      False             True
# 3      False       True      False      False      False             True
# 4      False      False      False      False      False            False
#
#    day_of_week_thu  day_of_week_tue  day_of_week_wed  macro_eco1
# 0            False            False             True    0.013012
# 1            False            False             True    0.013012
# 2            False            False            False   -2.181465
# 3            False            False            False    1.200832
# 4            False             True            False   -2.813321
#
# [5 rows x 38 columns]

# %% [markdown]
# seperate X/Y

# %%
X_train = df_train.drop("y", axis=1)
y_train = df_train["y"]

X_test = df_test.drop("y", axis=1)
y_test = df_test["y"]

# %%
X_test = X_test[X_train.columns]

# %%
pipeline = Pipeline([
    # ("scaler", StandardScaler()),
    ("model", LogisticRegression(max_iter=1000, random_state=42))
])

# %%
# train
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('model', LogisticRegression(max_iter=1000, random_state=42))])

# %%
# predict
y_pred = pipeline.predict(X_test)
y_prob = pipeline.predict_proba(X_test)[:, 1]

# %%
print("=== Base Model ===")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("AUC:", roc_auc_score(y_test, y_prob))
# Out:
# === Base Model ===
# Accuracy: 0.8982762806506434
# AUC: 0.7969054407047502

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "model__C": [0.01, 0.1, 1, 10],
    "model__penalty": ["l1", "l2"],
    "model__solver": ["liblinear"]
}

grid = GridSearchCV(
    pipeline,
    param_grid,
    cv=5,
    scoring="roc_auc",
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Params:", grid.best_params_)
# Out:
# Best Params: {'model__C': 1, 'model__penalty': 'l1', 'model__solver': 'liblinear'}
# c:\Users\konkanok\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\konkanok\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(

# %%
best_model = grid.best_estimator_

y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

print("=== Tuned Model ===")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("AUC:", roc_auc_score(y_test, y_prob))
print(classification_report(y_test, y_pred))
# Out:
# === Tuned Model ===
# Accuracy: 0.8983976693372178
# AUC: 0.7967805822208596
#               precision    recall  f1-score   support
#
#        False       0.91      0.99      0.95      7310
#         True       0.68      0.18      0.29       928
#
#     accuracy                           0.90      8238
#    macro avg       0.79      0.59      0.62      8238
# weighted avg       0.88      0.90      0.87      8238
# '\n=== Tuned Model ===\nAccuracy: 0.8983976693372178\nAUC: 0.7967768969055145\n'

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.show()

# %%
LogisticRegression(max_iter=1000, class_weight="balanced")
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %% [markdown]
# # Export Model

# %%
import json
import joblib

model_path = "model/logreg_model.joblib"
meta_path = "model/logreg_meta.json"

# Save fitted pipeline/model
joblib.dump(best_model, model_path)

# Save metadata
meta = {
    "feature_names": X_train.columns.tolist(),
}
with open(meta_path, "w", encoding="utf-8") as f:
    json.dump(meta, f, indent=2)
