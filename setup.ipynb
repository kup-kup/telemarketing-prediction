# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\konkanok\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\konkanok\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ucimlrepo) (3.0.1)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\konkanok\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from ucimlrepo) (2026.2.25)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\konkanok\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\konkanok\appdata\roaming\python\python314\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\konkanok\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\konkanok\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ucimlrepo import fetch_ucirepo 

# fetch dataset 
bank_marketing = fetch_ucirepo(id=222)

# %%
import os

# create directory if it doesn't exist
os.makedirs('data', exist_ok=True)
os.makedirs('output', exist_ok=True)

# aggregate data into a single dataframe
import pandas as pd

# data (as pandas dataframes) 
X = bank_marketing.data.features 
y = bank_marketing.data.targets 
df = pd.DataFrame(X, columns=bank_marketing.data.feature_names)
df['y'] = y

# save data to csv files
df.to_csv('data/bank-additional-full.csv', index=False)
